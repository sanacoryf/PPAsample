# %%
# %matplotlib notebook

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
plt.plot(3,2,'.')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.plot(4,5,'*')

# %%
# ?plt.plot

# %%
plt.clf()

# %%
x = [1,2,3,4]
y = [4,5,6,7]
plt.plot(x,y)

# %%
plt.plot(4,5,'*')
